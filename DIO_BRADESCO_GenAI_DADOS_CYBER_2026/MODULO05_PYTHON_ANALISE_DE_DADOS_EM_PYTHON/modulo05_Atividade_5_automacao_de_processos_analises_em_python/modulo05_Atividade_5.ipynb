# %% [markdown]
# # 📂 Automação de processos e análises com Python
#
# **Professora:** Dra. Isadora Garcia Ferrão
#
# 📧 [instagram](https://www.instagram.com/isadora.ferrao/)
#
# 🌐 [linkedin](https://www.linkedin.com/in/isadora-ferrao/)
#
# ---

# %% [markdown]
# ## Introdução à automação
#
# ## Conceito de automação
#
# Automação é o processo de executar tarefas automaticamente usando programas.
#
# Em vez de executar tarefas manualmente, criamos scripts que realizam essas tarefas de forma automática.
#
# Isso permite:
#
# - economizar tempo
# - reduzir erros
# - processar grandes volumes de dados

# %% [markdown]
# ## Cenários reais de automação
#
# A automação é usada em várias áreas:
#
# - geração automática de relatórios
# - coleta de dados da internet
# - processamento diário de arquivos
# - atualização de bancos de dados
# - monitoramento de sistemas
#
# Python é muito usado para automação por ser simples e poderoso.

# %% [markdown]
# # Manipulação automatizada de arquivos
#
# ## Processamento automático de arquivos
#
# Uma das automações mais comuns é processar arquivos automaticamente.
#
# Por exemplo:
#
# - ler arquivos de dados
# - calcular métricas
# - gerar relatórios

# %%
import csv

total = 0

with open("vendas.txt","w") as f:
    f.write("100\n200\n150\n300")

# %%
with open("vendas.txt","r") as f:

    for linha in f:
        valor = int(linha.strip())
        total += valor

print("Total de vendas:", total)
# Out:
# Total de vendas: 750

# %% [markdown]
# # Integração com APIs e bancos
#
# ## Coleta automática de dados
#
# Uma API permite que sistemas compartilhem dados automaticamente.
#
# Podemos usar APIs para coletar dados da internet.

# %%
import requests

url = "https://api.agify.io/?name=ana"

resposta = requests.get(url)

dados = resposta.json()

print(dados)
# Out:
# {'count': 281360, 'name': 'ana', 'age': 44}

# %% [markdown]
# ## Integração com banco de dados
#
# Também podemos automatizar o armazenamento de dados em bancos de dados.

# %%
import sqlite3

conn = sqlite3.connect("dados.db")

cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS usuarios(
nome TEXT,
idade INTEGER
)
""")

conn.commit()

print("Tabela criada com sucesso")
# Out:
# Tabela criada com sucesso

# %%
cursor.execute(
    "INSERT INTO usuarios VALUES (?,?)",
    ("Ana", 25)
)

conn.commit()

print("Usuário inserido no banco de dados")
# Out:
# Usuário inserido no banco de dados

# %%
cursor.execute("SELECT * FROM usuarios")

dados = cursor.fetchall()

print("Usuários no banco:")

for usuario in dados:
    print(usuario)
# Out:
# Usuários no banco:
# ('Ana', 25)

# %%
conn.close()

print("Conexão com o banco encerrada")
# Out:
# Conexão com o banco encerrada

# %% [markdown]
# # Agendamento de tarefas
#
# ## Scripts programados
#
# Em sistemas reais, scripts podem ser executados automaticamente em horários específicos.

# %%
import datetime

agora = datetime.datetime.now()

print("Script executado em:", agora)
# Out:
# Script executado em: 2026-08-18 11:15:43.341890

# %%
import datetime

def executar_relatorio():

    agora = datetime.datetime.now()

    print("Gerando relatório...")
    print("Horário:", agora)

executar_relatorio()
# Out:
# Gerando relatório...
# Horário: 2026-08-18 11:15:53.302405

# %% [markdown]
# ## Cron Jobs
#
# Em sistemas Linux utilizamos **cron jobs** para agendar tarefas.
#
# Exemplo:
#
# Executar um script todos os dias às 8h:
#
# 0 8 * * * python script.py

# %%
import datetime

def gerar_relatorio():

    vendas = [120, 200, 150, 300]

    total = sum(vendas)

    agora = datetime.datetime.now()

    print("Relatório gerado em:", agora)
    print("Total de vendas:", total)

gerar_relatorio()
# Out:
# Relatório gerado em: 2026-08-18 11:20:12.205548
# Total de vendas: 770

# %% [markdown]
# ## Como isso funciona na prática
#
# Fluxo real de automação:
#
# 1️⃣ criamos um script Python (ex: `relatorio.py`)
# 2️⃣ adicionamos um cron job no servidor
#
# Exemplo de cron job:
#
# 0 8 * * * python relatorio.py
#
# 3️⃣ o sistema executará o script automaticamente todos os dias às 08:00.

# %% [markdown]
# ## Monitoramento
#
# Quando automatizamos processos, precisamos monitorar se os scripts estão funcionando corretamente.
#
# Uma forma comum de fazer isso é usando **logs**.

# %%
import logging

logging.basicConfig(level=logging.INFO)

logging.info("Script de automação iniciado")
# Out:
# INFO:root:Script de automação iniciado

# %%
import logging

logging.basicConfig(level=logging.INFO)

def processar_dados():

    logging.info("Processamento iniciado")

    vendas = [100, 200, 150]

    total = sum(vendas)

    logging.info("Total calculado: %s", total)

processar_dados()
# Out:
# INFO:root:Processamento iniciado
# INFO:root:Total calculado: 450

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

logging.debug("Informação de depuração")
logging.info("Processo iniciado")
logging.warning("Possível problema detectado")
logging.error("Erro na execução")
# Out:
# INFO:root:Processo iniciado
# WARNING:root:Possível problema detectado
# ERROR:root:Erro na execução

# %% [markdown]
# # Projeto prático de automação
#
# ## O que é um pipeline de dados?
#
# Um pipeline de dados é um processo automatizado que executa várias etapas:
#
# 1. coleta de dados
# 2. processamento
# 3. análise
# 4. geração de resultados
#
# Pipelines são muito usados em:
#
# - análise de dados
# - engenharia de dados
# - relatórios automáticos

# %% [markdown]
# ## Dataset real utilizado
#
# Vamos utilizar um dataset real de **vendas de e-commerce**.
#
# Esse dataset contém:
#
# - produtos vendidos
# - quantidade
# - preço
# - país da venda

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"

df = pd.read_csv(url)

df.head()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Salvar o DataFrame em CSV
df.to_csv("tips.csv", index=False)

# %% [markdown]
# ## Processamento automático dos dados

# %%
total_gorjetas = df["tip"].sum()

print("Total de gorjetas:", total_gorjetas)
# Out:
# Total de gorjetas: 731.5799999999999

# %%
gorjetas_por_dia = df.groupby("day")["tip"].sum()

print(gorjetas_por_dia)
# Out:
# day
# Fri      51.96
# Sat     260.40
# Sun     247.39
# Thur    171.83
# Name: tip, dtype: float64

# %% [markdown]
# ## Criando um pipeline automatizado

# %%
def pipeline_restaurante():

    url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"

    df = pd.read_csv(url)

    total_gorjetas = df["tip"].sum()

    relatorio = pd.DataFrame({
        "total_gorjetas":[total_gorjetas]
    })

    relatorio.to_csv("relatorio_gorjetas.csv", index=False)

    print("Pipeline executado com sucesso")
    print("Total de gorjetas:", total_gorjetas)

pipeline_restaurante()
# Out:
# Pipeline executado com sucesso
# Total de gorjetas: 731.5799999999999
