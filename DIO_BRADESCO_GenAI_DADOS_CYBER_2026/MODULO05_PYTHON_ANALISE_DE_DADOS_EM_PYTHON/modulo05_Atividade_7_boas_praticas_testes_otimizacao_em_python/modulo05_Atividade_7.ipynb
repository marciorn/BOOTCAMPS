# %% [markdown]
# # 📂 Boas Práticas, testes e otimização de código em Python
#
# **Professora:** Dra. Isadora Garcia Ferrão
#
# 📧 [instagram](https://www.instagram.com/isadora.ferrao/)
#
# 🌐 [linkedin](https://www.linkedin.com/in/isadora-ferrao/)
#
# ---

# %% [markdown]
# ## Introdução às boas práticas
#
# ## O que é clean code?
#
# Clean Code significa escrever código que seja:
#
# - fácil de ler
# - fácil de entender
# - fácil de manter
#
# Um bom código não é apenas funcional, ele também é **organizado e claro**.
#
# 👉 "Código é lido mais vezes do que escrito"

# %% [markdown]
# ## Exemplo ruim vs bom

# %%
# código ruim

X = 10
Y = 20
Z = X+Y
print(Z)
# Out:
# 30

# %%
# código melhor

numero1 = 10
numero2 = 20
soma = numero1 + numero2

print(soma)
# Out:
# 30

# %% [markdown]
# ## Regras importantes
#
# - nomes claros
# - funções pequenas
# - evitar "mágica" no código
# - comentar apenas quando necessário

# %% [markdown]
# # Organização de Projetos
#
# ## Estrutura de pastas
#
# Projetos organizados facilitam a manutenção.
#
# Exemplo de estrutura:
#
#
# projeto/
#
# │
#
# ├── src/
#
# │   ├── main.py
#
# │   ├── utils.py
#
# │
#
# ├── tests/
#
# │   └── test_utils.py
#
# │
#
# ├── data/
#
# └── requirements.txt

# %% [markdown]
# ## Modularização
#
# Separar responsabilidades:
#
# - cálculo → utils.py
# - execução → main.py
# - testes → tests/

# %%
# função em módulo separado

def calcular_soma(a,b):
  return a+b

# %%
# uso da função

resultado = calcular_soma(10,5)

print(resultado)
# Out:
# 15

# %% [markdown]
# ## O que são testes?
#
# Testes garantem que o código está funcionando corretamente.
#
# Eles ajudam a:
#
# - evitar erros
# - validar funcionalidades
# - facilitar manutenção

# %% [markdown]
# ## Testes unitários

# %%
def soma(a,b):
  return a+b

#teste simples
assert soma(2,3) == 5

# %% [markdown]
# ## Usando pytest
#
# Pytest é uma ferramenta para criar testes automatizados.

# %%
def test_soma():
  assert soma(2,2) == 4

# %% [markdown]
# ## O que é refatoração?
#
# Refatorar significa melhorar o código sem alterar seu funcionamento.

# %%
def calc(a,b):
  return a+b

# %%
# Melhorando a escrita do código

def calcular_soma(numero1, numero2):
  return numero1+numero2

# %%
def processar(lista):
  resultado = []
  for i in lista:
    if i > 10:
      resultado.append(i*2)
    return resultado

# %%
# Melhorando a escrita do código

def processar_numeros(lista):
  return [numero * 2 for numero in lista if numero > 10]

# %%
lista = [1,2,3,4,5,11,12,13,14]
processar_numeros(lista)
# Out:
# [22, 24, 26, 28]

# %% [markdown]
# Melhorias:
#
# - menos código
# - mais legível
# - mais fácil de manter

# %% [markdown]
# ## Redução de complexidade
#
# Evite código muito complicado.
#
# Prefira:
#
# - funções simples
# - código dividido em partes

# %%
# código complexo

def processar(lista):
  return [x*2 for x in lista if x > 10]

# %% [markdown]
# ## O que é performance?
#
# Performance é a velocidade e eficiência do código.
#
# ## Profiling
#
# Profiling é analisar o desempenho do código.

# %%
import time

inicio = time.time()

for i in range(1000000):
    pass

fim = time.time()

print("Tempo:", fim - inicio)
# Out:
# Tempo: 0.11263585090637207

# %% [markdown]
# ## Melhorando performance

# %%
# exemplo com lista
numeros = list(range(1000000))

# forma rápida
soma = sum(numeros)

print(soma)
# Out:
# 499999500000

# %% [markdown]
# # Projeto Final
#
# Vamos aplicar tudo:
#
# - organização
# - função reutilizável
# - teste
# - performance

# %%
def calcular_total_vendas(vendas):
    return sum(vendas)


dados = [100, 200, 300, 400]

resultado = calcular_total_vendas(dados)

print("Total:", resultado)
# Out:
# Total: 1000
