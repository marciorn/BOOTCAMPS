# %% [markdown]
# # 📂 Bibliotecas essenciais de Python para análise de dados
#
# **Professora:** Dra. Isadora Garcia Ferrão
#
# 📧 [instagram](https://www.instagram.com/isadora.ferrao/)
#
# 🌐 [linkedin](https://www.linkedin.com/in/isadora-ferrao/)
#
# ---

# %% [markdown]
# ## Introdução às bibliotecas de dados
#
# Python possui MUITAS bibliotecas para trabalhar com dados.
#
# As três bibliotecas mais utilizadas são:
#
# - **NumPy** → computação numérica e arrays
# - **Pandas** → manipulação de dados em tabelas
# - **Matplotlib** → criação de gráficos

# %%
# importando bibliotecas

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## O que é NumPy?
#
# NumPy é uma biblioteca usada para trabalhar com **arrays e operações matemáticas eficientes**.
#
# Ela é muito mais rápida que listas comuns do Python para operações numéricas.

# %%
import numpy as np

array = np.array([1, 2, 3, 4, 5])

print(array)
# Out:
# [1 2 3 4 5]

# %%
# Criando um array
dados = np.array([10, 20, 30, 40, 50])

# Calculando a média
media = np.mean(dados)

soma = np.sum(dados)

print("Média:", media)
print("Média:", soma)
# Out:
# Média: 30.0
# Média: 150

# %% [markdown]
# ## O que é Pandas?
#
# Pandas é usado para manipular **dados estruturados**, como tabelas.
#
# A principal estrutura de dados é o **DataFrame**, que funciona como uma planilha.

# %%
import pandas as pd

dados = {
    "nome": ["Ana", "Carlos", "Maria"],
    "idade": [25, 30, 28]
}

df = pd.DataFrame(dados)

print(df)
# Out:
#      nome  idade
# 0     Ana     25
# 1  Carlos     30
# 2   Maria     28

# %%
df.head()
# Out:
#      nome  idade
# 0     Ana     25
# 1  Carlos     30
# 2   Maria     28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nome    3 non-null      object
#  1   idade   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %% [markdown]
# ## O que é Matplotlib?
#
# Matplotlib é uma biblioteca usada para **criar gráficos e visualizações de dados**.

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [10,20,25,30,32]

plt.plot(x,y)
plt.show()

# %% [markdown]
# # Manipulação de dados
#
# ## Arrays com NumPy
#
# Arrays são estruturas usadas para armazenar **vários valores numéricos** de forma eficiente.

# %%
import numpy as np

numeros = np.array([10, 20, 30, 40])

print(numeros)
# Out:
# [10 20 30 40]

# %%
# operações com arrays

numeros = np.array([1,2,3,4])

resultado = numeros * 2
resultado2 = numeros ** 3

print(resultado)
print(resultado2)
# Out:
# [2 4 6 8]
# [ 1  8 27 64]

# %% [markdown]
# ## DataFrames com Pandas
#
# DataFrames representam **tabelas de dados**.

# %%
import pandas as pd

dados = {
    "produto": ["Notebook", "Mouse", "Teclado"],
    "preco": [3500, 120, 200]
}

df = pd.DataFrame(dados)

print(df)
# Out:
#     produto  preco
# 0  Notebook   3500
# 1     Mouse    120
# 2   Teclado    200

# %% [markdown]
# ## Leitura de dados
#
# O Pandas permite ler arquivos como:
#
# - CSV
# - Excel
# - JSON

# %%
# Criar o arquivo CSV

import pandas as pd

dados = {
    "produto": ["Notebook", "Mouse", "Teclado"],
    "preco": [3500, 120, 200]
}

df = pd.DataFrame(dados)

df.to_csv("dados.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("dados.csv")

print(df)
# Out:
#     produto  preco
# 0  Notebook   3500
# 1     Mouse    120
# 2   Teclado    200

# %%
# Transformar o arquivo CSV para EXCEL

import pandas as pd

# Lê o arquivo CSV
df = pd.read_csv("dados.csv")

# Salva como Excel no mesmo diretório
df.to_excel("dados.xlsx", index=False)

# %%
# Transformar o arquivo EXCEL para CSV

import pandas as pd

# Lê o arquivo CSV
df = pd.read_excel("dados.xlsx")

# Salva como Excel no mesmo diretório
df.to_csv("dados2.csv", index=False)

# %% [markdown]
# ## Operações básicas
#
# Podemos acessar colunas e realizar cálculos.

# %%
import pandas as pd

df = pd.read_csv("dados.csv")

print(df)
# Out:
#     produto  preco
# 0  Notebook   3500
# 1     Mouse    120
# 2   Teclado    200

# %%
print(df["preco"])
# Out:
# 0    3500
# 1     120
# 2     200
# Name: preco, dtype: int64

# %% [markdown]
# ## Operações estatísticas

# %%
# Calculando a média de preços

df["preco"].mean()
# Out:
# 1273.3333333333333

# %%
# Calculando o desvio padrão dos preços

df["preco"].std()
# Out:
# 1928.764716945365

# %%
df["produto"].count()
# Out:
# 3

# %%
df.describe()
# Out:
#              preco
# count     3.000000
# mean   1273.333333
# std    1928.764717
# min     120.000000
# 25%     160.000000
# 50%     200.000000
# 75%    1850.000000
# max    3500.000000

# %% [markdown]
# ## Agrupamentos
#
# Podemos agrupar dados por categorias.

# %%
dados = {
    "produto": ["Notebook","Mouse","Mouse","Teclado", "Teclado"],
    "preco": [3500,120,150,200,230]
}

df = pd.DataFrame(dados)

df.groupby("produto").mean()
# Out:
#            preco
# produto
# Mouse      135.0
# Notebook  3500.0
# Teclado    215.0

# %% [markdown]
# # Visualização com matplotlib

# %%
# Gráfico de linhas

import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,15,20,30]

plt.plot(x,y)
plt.show()

# %%
# Gráfico de barras

produtos = ["Notebook","Mouse","Teclado"]
vendas = [15,50,30]

plt.bar(produtos,vendas)
plt.show()

# %%
# Gráfico de dispersão

x = [1,2,3,4,5]
y = [2,4,5,4,5]

plt.scatter(x,y)
plt.show()

# %% [markdown]
# # Integração das bibliotecas
#
# Na prática, usamos **NumPy, Pandas e Matplotlib juntos**.
#
# Fluxo típico de análise de dados:
#
# 1️⃣ ler dados
# 2️⃣ processar dados
# 3️⃣ analisar dados
# 4️⃣ visualizar dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

dados = {
    "produto": ["Notebook","Mouse","Teclado"],
    "vendas": [15,50,30]
}

df = pd.DataFrame(dados)

plt.bar(df["produto"], df["vendas"])

plt.show()
