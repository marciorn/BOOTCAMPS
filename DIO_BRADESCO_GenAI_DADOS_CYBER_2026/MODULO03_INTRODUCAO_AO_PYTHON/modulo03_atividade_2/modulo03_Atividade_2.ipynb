# %% [markdown]
# # TIPOS DE DADOS

# %%
print(1+10)
# Out:
# 11

# %%
1+10
# Out:
# 11

# %%
print(1.5+1+0.5)
# Out:
# 3.0

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # MODO ITERATIVO

# %%
dir(100) #Métodos disponíveis para o objeto do tipo int 100
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
help(100)
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
# ...

# %% [markdown]
# # VARIÁVEIS E CONSTANTES

# %%
nome = "Guilherme"
idade = 28

# %%
print(nome, idade)
# Out:
# Guilherme 28

# %%
print(f"O professor {nome} tem {idade} anos.")
# Out:
# O professor Guilherme tem 28 anos.

# %%
nome, idade = "Giovanna", 27

print(nome, idade)
# Out:
# Giovanna 27

# %%
limite_saque_diario = 1000
print(limite_saque_diario)

BRAZILIAN_STATES = ["SP", "RJ", "SC", "RS"]
print(BRAZILIAN_STATES)
# Out:
# 1000
# ['SP', 'RJ', 'SC', 'RS']

# %% [markdown]
# # CONVERSÃO DE TIPOS

# %%
print(int(1.97348728))
print(int("10"))
print(float("10.10"))
print(float(100))
# Out:
# 1
# 10
# 10.1
# 100.0

# %%
valor = 10
valor_str = str(valor)
print(type(valor))
print(type(valor_str))
# Out:
# <class 'int'>
# <class 'str'>

# %%
print(95 / 2)
print(95 // 2)
# Out:
# 47.5
# 47

# %%
preco = 10.5
idade = 28

# %%
preco_str = str(preco)
print(preco_str)
print(type(preco_str))
# Out:
# 10.5
# <class 'str'>

# %%
idade_str = str(idade)
print(idade_str)
type(idade_str)
# Out:
# 28
# str

# %%
soma = preco_str + idade_str
soma
# Out:
# '10.528'

# %%
type(soma)
# Out:
# str

# %%
print(f"Preço: R$ {preco_str} e idade: {idade_str}")
# Out:
# Preço: R$ 10.5 e idade: 28

# %%
preco_float = float(preco)
print(preco_float)
type(preco_float)
# Out:
# 10.5
# float

# %%
idade_float = float(idade)
print(idade_float)
type(idade_float)
# Out:
# 28.0
# float

# %%
soma = preco_float + idade_float
soma
# Out:
# 38.5

# %%
type(soma)
# Out:
# float

# %%
print(f"Preço: R$ {preco_float} e idade: {idade_float}")
# Out:
# Preço: R$ 10.5 e idade: 28.0

# %% [markdown]
# # FUNÇÕES DE ENTRADA E SAÍDA

# %%
nome = input("Informe o seu nome: ")
idade = input("Informe a sua idade: ")

print(nome, idade)
print(nome, idade, end="...\n")
print(nome, idade, sep="#", end="...\n")
print(nome, idade, sep="#")
# Out:
# Informe o seu nome:  MARCIO
# Informe a sua idade:  28
# MARCIO 28
# MARCIO 28...
# MARCIO#28...
# MARCIO#28

# %%
numero_1 = int(input("Informe o número inteiro: "))
numero_2 = float(input("Informe o número decimal: "))
print(numero_1, numero_2, end="...\n")

soma = numero_1 + numero_2
print(soma, end="...\n")
print(f"A soma dos números {numero_1} + {numero_2} é igual a {soma}.")
# Out:
# Informe o número inteiro:  23
# Informe o número decimal:  35.5
# 23 35.5...
# 58.5...
# A soma dos números 23 + 35.5 é igual a 58.5.

# %%
print(soma)
type(soma)
# Out:
# 58.5
# float
